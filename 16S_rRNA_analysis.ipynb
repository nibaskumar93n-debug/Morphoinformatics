# %% [markdown]
# <a href="https://colab.research.google.com/github/nibaskumar93n-debug/Morphoinformatics/blob/main/16S_rRNA_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !bash /content/ena-file-download-selected-files-20251220-1302.sh
# Out:
# --2025-12-20 13:03:44--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR120/098/SRR12059998/SRR12059998_2.fastq.gz
#            => ‘SRR12059998_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR120/098/SRR12059998 ... done.
# ==> SIZE SRR12059998_2.fastq.gz ... 3559338
# ==> PASV ... done.    ==> RETR SRR12059998_2.fastq.gz ... done.
# Length: 3559338 (3.4M) (unauthoritative)
#
# SRR12059998_2.fastq 100%[===================>]   3.39M  1.25MB/s    in 2.7s
#
# 2025-12-20 13:03:48 (1.25 MB/s) - ‘SRR12059998_2.fastq.gz’ saved [3559338]
#
# --2025-12-20 13:03:48--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR120/095/SRR12059995/SRR12059995_1.fastq.gz
#            => ‘SRR12059995_1.fastq.gz’
# ...

# %%
# !mkdir -p output_folder
# !cd output_folder && bash /content/gastric.sh
# Out:
# --2025-12-20 12:29:53--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR120/087/SRR12060187/SRR12060187_1.fastq.gz
#            => ‘SRR12060187_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR120/087/SRR12060187 ... done.
# ==> SIZE SRR12060187_1.fastq.gz ... 4784430
# ==> PASV ... done.    ==> RETR SRR12060187_1.fastq.gz ... done.
# Length: 4784430 (4.6M) (unauthoritative)
#
# SRR12060187_1.fastq 100%[===================>]   4.56M  5.94MB/s    in 0.8s
#
# 2025-12-20 12:29:55 (5.94 MB/s) - ‘SRR12060187_1.fastq.gz’ saved [4784430]
#
# --2025-12-20 12:29:55--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR120/092/SRR12059992/SRR12059992_2.fastq.gz
#            => ‘SRR12059992_2.fastq.gz’
# ...

# %%
# Install Java (required for FastQC)
# !apt-get update
# !apt-get install -y default-jre

# Download and install FastQC
# !wget https://www.bioinformatics.babraham.ac.uk/projects/fastqc/fastqc_v0.12.1.zip
# !unzip fastqc_v0.12.1.zip
# !chmod +x FastQC/fastqc

# Add to PATH
import os
os.environ['PATH'] += ':/content/FastQC'
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,205 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,858 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,633 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !mkdir -p fastqc_results

# %%
# !fastqc /content/raw_fastq/*.fastq* -o fastqc_results1
# Out:
# Streaming output truncated to the last 5000 lines.
# Analysis complete for SRR12060013_2.fastq.gz
# Started analysis of SRR12060014_1.fastq.gz
# Approx 5% complete for SRR12060014_1.fastq.gz
# Approx 10% complete for SRR12060014_1.fastq.gz
# Approx 15% complete for SRR12060014_1.fastq.gz
# Approx 20% complete for SRR12060014_1.fastq.gz
# Approx 25% complete for SRR12060014_1.fastq.gz
# Approx 30% complete for SRR12060014_1.fastq.gz
# Approx 35% complete for SRR12060014_1.fastq.gz
# Approx 40% complete for SRR12060014_1.fastq.gz
# Approx 45% complete for SRR12060014_1.fastq.gz
# Approx 50% complete for SRR12060014_1.fastq.gz
# Approx 55% complete for SRR12060014_1.fastq.gz
# Approx 60% complete for SRR12060014_1.fastq.gz
# Approx 65% complete for SRR12060014_1.fastq.gz
# Approx 70% complete for SRR12060014_1.fastq.gz
# Approx 75% complete for SRR12060014_1.fastq.gz
# Approx 80% complete for SRR12060014_1.fastq.gz
# Approx 85% complete for SRR12060014_1.fastq.gz
# ...

# %%
# Zip the folder
# !zip -r fastqc_results1.zip fastqc_results1/

# Download it
from google.colab import files
files.download('fastqc_results1.zip')
# Out:
#   adding: fastqc_results1/ (stored 0%)
#   adding: fastqc_results1/SRR12060119_2_fastqc.html (deflated 56%)
#   adding: fastqc_results1/SRR12060029_2_fastqc.html (deflated 57%)
#   adding: fastqc_results1/SRR12060114_2_fastqc.zip (stored 0%)
#   adding: fastqc_results1/SRR12060020_1_fastqc.zip (stored 0%)
#   adding: fastqc_results1/SRR12060048_2_fastqc.html (deflated 55%)
#   adding: fastqc_results1/SRR12060041_1_fastqc.html (deflated 57%)
#   adding: fastqc_results1/SRR12060083_2_fastqc.html (deflated 56%)
#   adding: fastqc_results1/SRR12060166_2_fastqc.html (deflated 57%)
#   adding: fastqc_results1/SRR12060159_1_fastqc.html (deflated 57%)
#   adding: fastqc_results1/SRR12059993_2_fastqc.html (deflated 56%)
#   adding: fastqc_results1/SRR12060094_2_fastqc.html (deflated 56%)
#   adding: fastqc_results1/SRR12060137_1_fastqc.html (deflated 57%)
#   adding: fastqc_results1/SRR12060169_2_fastqc.zip (stored 0%)
#   adding: fastqc_results1/SRR12059994_1_fastqc.zip (stored 0%)
# ...

# %%
# !fastqc --version
# Out:
# FastQC v0.12.1

# %%
# !pip install multiqc
# !multiqc --version
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.6/39.6 MB 50.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 117.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.2 MB/s eta 0:00:00
# ...
# multiqc, version 1.33

# %%
# !multiqc fastqc_results1 -o multiqc_report1
# !ls -lh multiqc_report1
# Out:
# /// ]8;id=603653;https://multiqc.info\MultiQC]8;;\ 🎄 v1.33
#
#        file_search | Search path: /content/fastqc_results1
#          searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 576/576
#             fastqc | Found 288 reports
#      write_results | Data        : multiqc_report1/multiqc_data
#      write_results | Report      : multiqc_report1/multiqc_report.html
#            multiqc | MultiQC complete
# total 5.3M
# drwxr-xr-x 2 root root 4.0K Dec 20 13:19 multiqc_data
# -rw-r--r-- 1 root root 5.3M Dec 20 13:19 multiqc_report.html

# %%
# Zip the folder
# !zip -r multiqc_report1.zip multiqc_report1/

# Download it
from google.colab import files
files.download('multiqc_report1.zip')
# Out:
#   adding: multiqc_report1/ (stored 0%)
#   adding: multiqc_report1/multiqc_report.html (deflated 74%)
#   adding: multiqc_report1/multiqc_data/ (stored 0%)
#   adding: multiqc_report1/multiqc_data/llms-full.txt (deflated 85%)
#   adding: multiqc_report1/multiqc_data/fastqc_per_base_sequence_quality_plot.txt (deflated 60%)
#   adding: multiqc_report1/multiqc_data/multiqc.parquet (deflated 81%)
#   adding: multiqc_report1/multiqc_data/fastqc_top_overrepresented_sequences_table.txt (deflated 67%)
#   adding: multiqc_report1/multiqc_data/fastqc_sequence_counts_plot.txt (deflated 69%)
#   adding: multiqc_report1/multiqc_data/fastqc_per_base_n_content_plot.txt (deflated 95%)
#   adding: multiqc_report1/multiqc_data/fastqc_overrepresented_sequences_plot.txt (deflated 55%)
#   adding: multiqc_report1/multiqc_data/fastqc_per_sequence_gc_content_plot_Percentages.txt (deflated 80%)
#   adding: multiqc_report1/multiqc_data/fastqc-status-check-heatmap.txt (deflated 92%)
# ...

# %%
# Install Miniconda
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# Initialize conda
import sys
sys.path.append('/usr/local/lib/python3.10/site-packages')

# Accept conda Terms of Service
# !conda config --set channel_priority flexible
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r

# Update conda
# !conda update -n base -c defaults conda -y
# Out:
# --2025-12-20 09:44:10--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156772981 (150M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 149.51M   141MB/s    in 1.1s
#
# 2025-12-20 09:44:12 (141 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [156772981/156772981]
#
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
# ...

# %%
# Install Miniconda (already done from previous step, skip if already installed)
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# Accept Terms of Service (already done)
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r


# Create QIIME2 environment with the correct URL (2024.10 version with py310)
# !conda env create -n qiime2-amplicon-2024.10 --file https://data.qiime2.org/distro/amplicon/qiime2-amplicon-2024.10-py310-linux-conda.yml

print("✓ QIIME2 installation complete!")
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
# Download Greengenes2 V4 (515F/806R) classifier
# !wget https://data.qiime2.org/classifiers/greengenes/gg_2022_10_backbone.v4.nb.qza
# Out:
# --2025-12-20 09:51:32--  https://data.qiime2.org/classifiers/greengenes/gg_2022_10_backbone.v4.nb.qza
# Resolving data.qiime2.org (data.qiime2.org)... 54.200.1.12
# Connecting to data.qiime2.org (data.qiime2.org)|54.200.1.12|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://s3-us-west-2.amazonaws.com/qiime2-data/classifiers/greengenes/gg_2022_10_backbone.v4.nb.qza [following]
# --2025-12-20 09:51:32--  https://s3-us-west-2.amazonaws.com/qiime2-data/classifiers/greengenes/gg_2022_10_backbone.v4.nb.qza
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.217.80, 52.92.136.96, 52.92.186.152, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.217.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48784298 (47M) [binary/octet-stream]
# Saving to: ‘gg_2022_10_backbone.v4.nb.qza’
#
# gg_2022_10_backbone 100%[===================>]  46.52M  31.3MB/s    in 1.5s
#
# ...

# %%
# Activate QIIME2 and test installation
# !source /usr/local/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && qiime info
# Out:
# System versions
# Python version: 3.10.14
# QIIME 2 release: 2024.10
# QIIME 2 version: 2024.10.1
# q2cli version: 2024.10.1
#
# Installed plugins
# alignment: 2024.10.0
# composition: 2024.10.0
# cutadapt: 2024.10.0
# dada2: 2024.10.0
# deblur: 2024.10.0
# demux: 2024.10.0
# diversity: 2024.10.0
# diversity-lib: 2024.10.0
# emperor: 2024.10.0
# feature-classifier: 2024.10.0
# feature-table: 2024.10.0
# fragment-insertion: 2024.10.0
# longitudinal: 2024.10.0
# metadata: 2024.10.0
# phylogeny: 2024.10.0
# quality-control: 2024.10.0
# quality-filter: 2024.10.0
# rescript: 2024.10.0
# sample-classifier: 2024.10.0
# stats: 0+unknown
# taxa: 2024.10.0
# types: 2024.10.0
# vizard: 0.0.1.dev0
# vsearch: 2024.10.0
#
# Application config directory
# /usr/local/envs/qiime2-amplicon-2024.10/var/q2cli
#
# Config
# Config Source: /usr/local/envs/qiime2-amplicon-2024.10/etc/qiime2_config.toml
#
# Getting help
# To get help with QIIME 2, visit https://qiime2.org
# ...

# %%
# !source /usr/local/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && \
qiime feature-classifier classify-sklearn \
  --i-classifier gg_2022_10_backbone.v4.nb.qza \
  --i-reads rep-seqs.qza \
  --o-classification taxonomy.qza

# %%
# !source /usr/local/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && qiime --version
# Out:
# q2cli version 2024.10.1
# Run `qiime info` for more version details.

# %%
# !source /usr/local/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && qiime --help
# Out:
# Usage: qiime [OPTIONS] COMMAND [ARGS]...
#
#   QIIME 2 command-line interface (q2cli)
#   --------------------------------------
#
#   To get help with QIIME 2, visit
#   https://qiime2.org.
#
#   To enable tab completion in Bash, run the
#   following command or add it to your
#   .bashrc/.bash_profile:
#
#       source tab-qiime
#
#   To enable tab completion in ZSH, run the
#   following commands or add them to your .zshrc:
#
#       autoload -Uz compinit && compinit
#       autoload bashcompinit && bashcompinit
#       source tab-qiime
#
# Options:
#   --version   Show the version and exit.
#   --help      Show this message and exit.
#
# Commands:
#   info                Display information...
#   tools               Tools for working with...
#   dev                 Utilities for...
#   alignment           Plugin for generating and
#                       manipulating alignments.
#   composition         Plugin for compositional
#                       data analysis.
# ...

# %%
# Create a separate conda environment for PICRUSt2
# !source /usr/local/etc/profile.d/conda.sh && \
conda create -n picrust2 -c bioconda -c conda-forge picrust2 -y
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - bioconda
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/picrust2
#
#   added / updated specs:
#     - picrust2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.15.1          |       hb03c661_0         572 KB  conda-forge
#     attr-2.5.2                 |       h39aace5_0          66 KB  conda-forge
#     binutils_impl_linux-64-2.45|default_hfdba357_104         3.6 MB  conda-forge
#     biom-format-2.1.16         |   py39h8cd3c5a_2         8.6 MB  conda-forge
#     bwidget-1.10.1             |       ha770c72_1         127 KB  conda-forge
#     c-ares-1.34.6              |       hb03c661_0         203 KB  conda-forge
#     ca-certificates-2025.11.12 |       hbd8a1cb_0         149 KB  conda-forge
# ...

# %%
# !source /usr/local/etc/profile.d/conda.sh && conda activate picrust2 && \
picrust2_pipeline.py -v
# Out:
# PICRUSt2 2.6.3

# %%
# !source /usr/local/etc/profile.d/conda.sh && conda activate picrust2 && \
picrust2_pipeline.py -h
# Out:
# usage: picrust2_pipeline.py
#        [-h]
#        -s
#        PATH
#        -i
#        PATH
#        -o
#        PATH
#        [-p PROCESSES]
#        [-t epa-ng|sepp]
#        [-r1 PATH]
#        [-r2 PATH]
#        [--in_traits IN_TRAITS]
#        [--custom_trait_tables_ref1 PATH]
#        [--custom_trait_tables_ref2 PATH]
#        [--marker_gene_table_ref1 PATH]
#        [--marker_gene_table_ref2 PATH]
#        [--pathway_map MAP]
#        [--reaction_func MAP]
#        [--no_pathways]
#        [--regroup_map ID_MAP]
#        [--no_regroup]
#        [--stratified]
#        [--max_nsti FLOAT]
#        [--min_reads INT]
#        [--min_samples INT]
#        [-m {mp,emp_prob,pic,scp,subtree_average}]
#        [-e EDGE_EXPONENT]
#        [--min_align MIN_ALIGN]
#        [--skip_minpath]
#        [--no_gap_fill]
#        [--coverage]
#        [--per_sequence_contrib]
#        [--wide_table]
#        [--skip_norm]
#        [--remove_intermediate]
#        [--verbose]
#        [-v]
#
# ...
