# %% [markdown]
# <a href="https://colab.research.google.com/github/nibaskumar93n-debug/Morphoinformatics/blob/main/QSAR_ovivai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /usr/bin/python3.real
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
import sys
# !{sys.executable} -m pip install -q rdkit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.1/37.1 MB 18.8 MB/s eta 0:00:00

# %%
import sys
# !{sys.executable} -m pip show rdkit
# Location should now match your sys.executable path
# Out:
# Name: rdkit
# Version: 2026.3.2
# Summary: A collection of chemoinformatics and machine-learning software written in C++ and Python
# Home-page: https://github.com/kuelumbus/rdkit-pypi
# Author: Christopher Kuenneth
# Author-email: chris@kuenneth.dev
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: numpy, Pillow
# Required-by:

# %%
from pathlib import Path
from warnings import filterwarnings
filterwarnings("ignore")

import pandas as pd
import numpy as np
import tensorflow as tf
from rdkit import Chem
from rdkit.Chem import MACCSkeys, Draw, rdFingerprintGenerator
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import metrics
import seaborn as sns
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint

print(f"✅ Python: {__import__('sys').version}")
print(f"✅ TensorFlow: {tf.__version__}")
print(f"✅ RDKit: {__import__('rdkit').__version__}")
print("✅ All imports successful!")
# Out:
# ✅ Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ✅ TensorFlow: 2.20.0
# ✅ RDKit: 2026.03.2
# ✅ All imports successful!
